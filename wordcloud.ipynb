# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
#read the respective ranked list of tweets
tweets = pd.read_csv('ranked-list-16.csv',usecols=['Text'])

# %%
tweets.head()
# Out:
#                                                 Text
# 0  Here are the official results of the OTHER RAC...
# 1  ~ Ghanaâ€™s President JohnDramaniMahama calls ...
# 2  @_Karried_ I never really practiced doing the ...
# 3  Icp should be between 5-15, cpp should be betw...
# 4  GHANA: MT @MacJordaN Pres. @JohnDramaniMahama ...

# %%
#determine what tweets you need for the different wordclouds
top_tweets = tweets[:100]
bottom_tweets = tweets[-1000:]

# %%
top_tweets.head()
# Out:
#                                                 Text
# 0  Here are the official results of the OTHER RAC...
# 1  ~ Ghanaâ€™s President JohnDramaniMahama calls ...
# 2  @_Karried_ I never really practiced doing the ...
# 3  Icp should be between 5-15, cpp should be betw...
# 4  GHANA: MT @MacJordaN Pres. @JohnDramaniMahama ...

# %%
def make_wordcloud(tweets,figure):
    comment_words = ' '
    stopwords = set(STOPWORDS) 
    
    for val in tweets['Text']: 
        # typecaste each val to string 
        val = str(val) 
        
        # split the value 
        tokens = val.split() 
        
        # Converts each token into lowercase 
        for i in range(len(tokens)): 
            tokens[i] = tokens[i].lower() 
            
        for words in tokens:
            comment_words = comment_words + words + ' '
            
    wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
                          min_font_size = 10).generate(comment_words)

    # plot the WordCloud image  
    plt.figure(figsize = (10, 10), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    filename = '../../Wordclouds/' + figure + '.png'
    plt.savefig(filename)
    plt.show()

# %%
make_wordcloud(top_tweets,'top-16-100')

# %%
bottom_tweets.head()
# Out:
#                                                    Text
# 3184  @MsPabii @alan_tsatsu @Nenetey_101 four years ...
# 3185  Another 4/5 years of shit yeaa? Ite kl Ghana.....
# 3186  U are the King the Lord has Made ..John 3:16 @...
# 3187  @JohnDramaniMahama Congrats! U need not disapp...
# 3188  He said 'because NanaAkufo-Addo didn't win, so...

# %%
make_wordcloud(bottom_tweets,'bottom-16-1000')
